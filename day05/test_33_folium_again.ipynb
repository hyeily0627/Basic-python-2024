# %%
# file : test_32_folium.ipynb
# desc : 지도 라이브러리 사용 계속
import folium

# %%
## 타일 종류, 마커 표시
map = folium.Map(location=[35.173999, 129.196649],zoom_start=20, tiles='cartodb positron')

folium.Marker([35.173999, 129.196649], popup='송정해수욕장').add_to(map) # 마커추가
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7196138c372a3eca1912fb0a65dfd437 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7196138c372a3eca1912fb0a65dfd437&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7196138c372a3eca1912fb0a65dfd437 = L.map(
#                 &quot;map_7196138c372a3eca1912fb0a65dfd437&quot;,
#                 {
#                     center: [35.173999, 129.196649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6cecb7de797c05c4aae6189041f83a7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6cecb7de797c05c4aae6189041f83a7.addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var marker_89e03a221b4c67eb63b139779db04a62 = L.marker(
#                 [35.173999, 129.196649],
#                 {}
#             ).addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#         var popup_7760675df01f889b91eeb8798b6bc0d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13124143acedac00be941f40282cbddc = $(`&lt;div id=&quot;html_13124143acedac00be941f40282cbddc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;송정해수욕장&lt;/div&gt;`)[0];
#                 popup_7760675df01f889b91eeb8798b6bc0d8.setContent(html_13124143acedac00be941f40282cbddc);
#
#
#
#         marker_89e03a221b4c67eb63b139779db04a62.bindPopup(popup_7760675df01f889b91eeb8798b6bc0d8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## 마커 종류 변경
folium.Marker([35.173999, 129.196649], popup='송정해수욕장', icon=folium.Icon(color='pink',icon='heart-empty')).add_to(map) 
map

## 아이콘 종류 참고 사이트 : https://getbootstrap.com/docs/3.3/components/
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7196138c372a3eca1912fb0a65dfd437 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7196138c372a3eca1912fb0a65dfd437&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7196138c372a3eca1912fb0a65dfd437 = L.map(
#                 &quot;map_7196138c372a3eca1912fb0a65dfd437&quot;,
#                 {
#                     center: [35.173999, 129.196649],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6cecb7de797c05c4aae6189041f83a7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e6cecb7de797c05c4aae6189041f83a7.addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var marker_89e03a221b4c67eb63b139779db04a62 = L.marker(
#                 [35.173999, 129.196649],
#                 {}
#             ).addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#         var popup_7760675df01f889b91eeb8798b6bc0d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13124143acedac00be941f40282cbddc = $(`&lt;div id=&quot;html_13124143acedac00be941f40282cbddc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;송정해수욕장&lt;/div&gt;`)[0];
#                 popup_7760675df01f889b91eeb8798b6bc0d8.setContent(html_13124143acedac00be941f40282cbddc);
#
#
#
#         marker_89e03a221b4c67eb63b139779db04a62.bindPopup(popup_7760675df01f889b91eeb8798b6bc0d8)
#         ;
#
#
#
#
#             tile_layer_e6cecb7de797c05c4aae6189041f83a7.addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var marker_6a817930260356384a34db07393d4cde = L.marker(
#                 [35.173999, 129.196649],
#                 {}
#             ).addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var icon_110f7328476982f45943e90d6232c6fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove-circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6a817930260356384a34db07393d4cde.setIcon(icon_110f7328476982f45943e90d6232c6fa);
#
#
#         var popup_000e4a473107b4dbf95777142d26c03e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41322e3e79fed11366f98d2609a89d76 = $(`&lt;div id=&quot;html_41322e3e79fed11366f98d2609a89d76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;송정해수욕장&lt;/div&gt;`)[0];
#                 popup_000e4a473107b4dbf95777142d26c03e.setContent(html_41322e3e79fed11366f98d2609a89d76);
#
#
#
#         marker_6a817930260356384a34db07393d4cde.bindPopup(popup_000e4a473107b4dbf95777142d26c03e)
#         ;
#
#
#
#
#             tile_layer_e6cecb7de797c05c4aae6189041f83a7.addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var marker_473ab766ad5426386e3bdded2d1a0682 = L.marker(
#                 [35.173999, 129.196649],
#                 {}
#             ).addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var icon_2de43ab5faa77fc90867eb403fd042d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;eye-open&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_473ab766ad5426386e3bdded2d1a0682.setIcon(icon_2de43ab5faa77fc90867eb403fd042d1);
#
#
#         var popup_14881fbe15cef3a21571f1391db1d41a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a68936e2865213abb6cef1b3bdc60405 = $(`&lt;div id=&quot;html_a68936e2865213abb6cef1b3bdc60405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;송정해수욕장&lt;/div&gt;`)[0];
#                 popup_14881fbe15cef3a21571f1391db1d41a.setContent(html_a68936e2865213abb6cef1b3bdc60405);
#
#
#
#         marker_473ab766ad5426386e3bdded2d1a0682.bindPopup(popup_14881fbe15cef3a21571f1391db1d41a)
#         ;
#
#
#
#
#             tile_layer_e6cecb7de797c05c4aae6189041f83a7.addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var marker_891daa7b736dce98e9e49c0bf85b218b = L.marker(
#                 [35.173999, 129.196649],
#                 {}
#             ).addTo(map_7196138c372a3eca1912fb0a65dfd437);
#
#
#             var icon_e58bd3249a13e299339f77a2690bc3b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart-empty&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;marker
